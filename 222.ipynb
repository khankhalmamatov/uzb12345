# %%
print("ASRRRR")
# Out:
# ASRRRR

# %%
print("Salom dunyo !!!")
print("alik")
print("alik")

print("Yangi o'zgarish qo'shildi.")
print("Yana bir yangi o'zgarish qo'shildi.")
# Out:
# Salom dunyo !!!
# alik
# Yangi o'zgarish qo'shildi.
# Yana bir yangi o'zgarish qo'shildi.
