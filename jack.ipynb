# %%
print("Jackson !!! ")
print("2-jackson")
print("2-jackson")
print("2-jackson")
print("2-jackson")
# Out:
# Jackson !!!
# 2-jackson
# 2-jackson
# 2-jackson
# 2-jackson

# %%
print("K")
print("2-jackson")
# Out:
# K
# 2-jackson
